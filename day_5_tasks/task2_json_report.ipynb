# %%
import json

# %%
with open("learner.json", "r") as f:
    data = json.load(f)

# %%
print(f"Name : {data['name']}")
print(f"Role : {data['role']}")
# Out:
# Name : Harsh Patidar
# Role : Data Intern

# %%
skills_upper = [skill.upper() for skill in data["skills"]]
skills_upper
# Out:
# ['PYTHON', 'PANDAS', 'NUMPY', 'GIT', 'SQL']

# %%
print(f"Skills : {', '.join(skills_upper)}")
# Out:
# Skills : PYTHON, PANDAS, NUMPY, GIT, SQL
