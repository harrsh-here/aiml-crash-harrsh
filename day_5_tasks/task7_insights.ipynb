# %%
import pandas as pd

# %%
df = pd.read_csv("learners.csv")

# %%
df.describe()
# Out:
#            score  joined_year
# count   9.000000    10.000000
# mean   83.666667  2023.000000
# std     7.921490     1.054093
# min    70.000000  2021.000000
# 25%    78.000000  2022.250000
# 50%    85.000000  2023.000000
# 75%    88.000000  2024.000000
# max    95.000000  2024.000000

# %%
df["role"].value_counts()
# Out:
# role
# Intern     4
# Analyst    3
# Manager    3
# Name: count, dtype: int64

# %% [markdown]
# ### Observation: Interns form the largest group in the dataset with 4 members.
